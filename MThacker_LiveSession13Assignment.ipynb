# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]

# %%
print my_list[4]
# Out:
# 39.0

# %%
my_list.append(55.2)

# %%
my_list.pop(5)
# Out:
# 60.0

# %%
ml2 = [i for i in my_list if i > 45]

# %%
ml2
# Out:
# [45.4, 47.4, 45.8, 55.2]

# %%
my_array = np.array(my_list)

# %%
np.mean(my_array)
# Out:
# 42.560000000000002

# %%
np.std(my_array)
# Out:
# 5.9709630713981143

# %%
lt45 = [i for i in my_array if i < 45]

# %%
lt45
# Out:
# [44.200000000000003,
#  36.799999999999997,
#  35.100000000000001,
#  39.0,
#  41.100000000000001,
#  35.600000000000001]

# %%
np.max(my_array)
# Out:
# 55.200000000000003

# %%
np.min(my_array)
# Out:
# 35.100000000000001

# %%
iris = pd.read_csv('C:\Users\Matthew\PycharmProjects\DS_HW13\iris.csv')

# %%
print iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = iris.drop('Id', axis=1)

# %%
print iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_setosa = pd.DataFrame(iris.loc[iris['Species'].isin(['Iris-setosa'])])

# %%
print iris_setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %%
Summary = iris.groupby('Species')

# %%
Summary.describe()
# Out:
#                        PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count      50.000000     50.000000      50.000000
#                 mean        1.464000      0.244000       5.006000
#                 std         0.173511      0.107210       0.352490
#                 min         1.000000      0.100000       4.300000
#                 25%         1.400000      0.200000       4.800000
#                 50%         1.500000      0.200000       5.000000
#                 75%         1.575000      0.300000       5.200000
#                 max         1.900000      0.600000       5.800000
# Iris-versicolor count      50.000000     50.000000      50.000000
#                 mean        4.260000      1.326000       5.936000
#                 std         0.469911      0.197753       0.516171
#                 min         3.000000      1.000000       4.900000
#                 25%         4.000000      1.200000       5.600000
# ...

# %%
bp = iris.boxplot(by = 'Species')

# %%
plt.show()

# %%
sns.pairplot(iris, hue = 'Species')

# %%
plt.show()
